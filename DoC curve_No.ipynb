# %%
#This is for 0mM TEMPO (Jack Shared on April 28th)

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

file_path='.\\circles_TEMPO_10,15,20,25mW_0,1,5mM\\0mM TEMPO\\25mW 0mM TEMPO\\intensity_data.csv'
df=pd.read_csv(file_path)
df.dropna(inplace=True)
#print(df.head(5))
time1=df['25mW_0_mM_TEMPO_T1_Time_s'].values
signal1=df['25mW_0_mM_TEMPO_T1_Intensity'].values

t30_1=next((time1[i] for i in range(len(signal1)) if signal1[i] >= 0.3), None)
t90_1=next((time1[i] for i in range(len(signal1)) if signal1[i] >= 0.9), None)


time2=df['25mW_0_mM_TEMPO_T2_Time_s'].values
signal2=df['25mW_0_mM_TEMPO_T2_Intensity'].values
t30_2=next((time2[i] for i in range(len(signal2)) if signal2[i] >= 0.3), None)
t90_2=next((time2[i] for i in range(len(signal2)) if signal2[i] >= 0.9), None)


print(f't30_1:{t30_1:.3f}s, t30_2:{t30_2:.3f}s, Time when signal reaches 30% DoC: {np.average([t30_1, t30_2]):.3f} s')
print(f't90_1:{t90_1:.3f}s, t90_2:{t90_2:.3f}s, Time when signal reaches 90% DoC: {np.average([t90_1, t90_2]):.3f} s')

for i in range(0,10):
    #print(i,signal1[i+1]-signal1[i])
    if np.abs((signal1[i+2]-signal1[i+1])/(signal1[i+1]-signal1[i]))>5:
        break
print('End of Inhibition T:',time1[i+1])
time1=time1[i+1:]
signal1=signal1[i+1:]
signal1=signal1-signal1[0]
signal1=signal1/signal1.max()


#plt.plot(time1,signal1,'--')

for i in range(0,10):
    #print(i,signal1[i+1]-signal1[i])
    if np.abs((signal2[i+2]-signal2[i+1])/(signal2[i+1]-signal2[i]))>10:
        break
print('End of Inhibition T:',time2[i+1])
time2=time2[i+1:]
signal2=signal2[i+1:]
signal2=signal2-signal2[0]
signal2=signal2/signal2.max()


def fitting_func(t,a,b):
    return 1-a*np.exp(np.minimum(b*(-t),0))

popt1, pcov1 = curve_fit(fitting_func, time1, signal1)
popt2, pcov2 = curve_fit(fitting_func, time2, signal2)
print('Fitted parameters for T1:', popt1)
print('Fitted parameters for T2:', popt2)
print(f'Average a={np.mean([popt1[0], popt2[0]]):.3f}')
print(f'Average b={np.mean([popt1[1], popt2[1]]):.3f}')

fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].scatter(time1, signal1, label='T1 Data', color='blue')
axes[0].plot(time1, fitting_func(time1, *popt1), label='T1 Fit', color='red')
axes[1].scatter(time2, signal2, label='T2 Data', color='green')
axes[1].plot(time2, fitting_func(time2, *popt2), label='T2 Fit', color='orange')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Normalized Intensity')
axes[1].set_xlabel('Time (s)')
axes[1].set_ylabel('Normalized Intensity')
axes[0].legend()
axes[1].legend()

fig.suptitle('0mM TEMPO 25mW- T1 and T2 Data with Fitted Curves')
fig.tight_layout()
plt.show()
# Out:
# t30_1:1.209s, t30_2:1.410s, Time when signal reaches 30% DoC: 1.309 s
# t90_1:3.223s, t90_2:3.223s, Time when signal reaches 90% DoC: 3.223 s
# End of Inhibition T: 0.402841
# End of Inhibition T: 0.4028496
# Fitted parameters for T1: [1.48809455 0.78159421]
# Fitted parameters for T2: [1.42132434 0.59067203]
# Average a=1.455
# Average b=0.686

# %%
#This is for 1mM TEMPO (Jack Shared on April 28th)

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

file_path='.\\circles_TEMPO_10,15,20,25mW_0,1,5mM\\1mM TEMPO\\15mW 1mM TEMPO\\intensity_data.csv'
df=pd.read_csv(file_path)
df.dropna(inplace=True)
#print(df.head(5))
time1=df['15mW_1_mM_TEMPO_T1_Time_s'].values
signal1=df['15mW_1_mM_TEMPO_T1_Intensity'].values
signal1=signal1/signal1.max()
t30_1=next((time1[i] for i in range(len(signal1)) if signal1[i] >= 0.3), None)
t90_1=next((time1[i] for i in range(len(signal1)) if signal1[i] >= 0.9), None)


time2=df['15mW_1_mM_TEMPO_T2_Time_s'].values
signal2=df['15mW_1_mM_TEMPO_T2_Intensity'].values
signal2=signal2/signal2.max()
t30_2=next((time2[i] for i in range(len(signal2)) if signal2[i] >= 0.3), None)
t90_2=next((time2[i] for i in range(len(signal2)) if signal2[i] >= 0.9), None)


print(f't30_1:{t30_1:.3f}s, t30_2:{t30_2:.3f}s, Time when signal reaches 30% DoC: {np.average([t30_1, t30_2]):.3f} s')
print(f't90_1:{t90_1:.3f}s, t90_2:{t90_2:.3f}s, Time when signal reaches 90% DoC: {np.average([t90_1, t90_2]):.3f} s')

for i in range(0,10):
    #print(i,signal1[i+1]-signal1[i])
    if np.abs((signal1[i+2]-signal1[i+1])/(signal1[i+1]-signal1[i]))>10:
        break
print('End of Inhibition T:',time1[i+1])
time1=time1[i+1:]
signal1=signal1[i+1:]

#plt.plot(time1,signal1,'--')

for i in range(0,10):
    #print(i,signal1[i+1]-signal1[i])
    if np.abs((signal2[i+2]-signal2[i+1])/(signal2[i+1]-signal2[i]))>10:
        break
print('End of Inhibition T:',time2[i+1])
time2=time2[i+1:]
signal2=signal2[i+1:]


def fitting_func(t,a,b):
    return 1-a*np.exp(np.minimum(b*(-t),0))

popt1, pcov1 = curve_fit(fitting_func, time1, signal1)
popt2, pcov2 = curve_fit(fitting_func, time2, signal2)
print('Fitted parameters for T1:', popt1)
print('Fitted parameters for T2:', popt2)
print(f'Average a={np.mean([popt1[0], popt2[0]]):.3f}')
print(f'Average b={np.mean([popt1[1], popt2[1]]):.3f}')

fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].scatter(time1, signal1, label='T1 Data', color='blue')
axes[0].plot(time1, fitting_func(time1, *popt1), label='T1 Fit', color='red')
axes[1].scatter(time2, signal2, label='T2 Data', color='green')
axes[1].plot(time2, fitting_func(time2, *popt2), label='T2 Fit', color='orange')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Normalized Intensity')
axes[1].set_xlabel('Time (s)')
axes[1].set_ylabel('Normalized Intensity')
axes[0].legend()
axes[1].legend()
fig.tight_layout()
plt.show()
# Out:
# t30_1:3.424s, t30_2:3.424s, Time when signal reaches 30% DoC: 3.424 s
# t90_1:6.446s, t90_2:6.446s, Time when signal reaches 90% DoC: 6.446 s
# End of Inhibition T: 0.2014356
# End of Inhibition T: 0.604273500000001
# Fitted parameters for T1: [1.33498796 0.29712416]
# Fitted parameters for T2: [1.4871454  0.31740499]
# Average a=1.411
# Average b=0.307
# D:\ABAQUS\temp\AppData\Local\Temp\ipykernel_19312\3114845527.py:31: RuntimeWarning: divide by zero encountered in scalar divide
#   if np.abs((signal1[i+2]-signal1[i+1])/(signal1[i+1]-signal1[i]))>5:
# D:\ABAQUS\temp\AppData\Local\Temp\ipykernel_19312\3114845527.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   if np.abs((signal2[i+2]-signal2[i+1])/(signal2[i+1]-signal2[i]))>1:
# D:\ABAQUS\temp\AppData\Local\Temp\ipykernel_19312\3114845527.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   if np.abs((signal2[i+2]-signal2[i+1])/(signal2[i+1]-signal2[i]))>1:

# %%
#This is for 5mM TEMPO (Jack Shared on April 28th)

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

file_path='.\\circles_TEMPO_10,15,20,25mW_0,1,5mM\\5mM TEMPO\\20mW 5mM TEMPO\\intensity_data.csv'
df=pd.read_csv(file_path)
df.dropna(inplace=True)
#df=df.dropna(subset=['10mW_5_mM_TEMPO_T1_Time_s','10mW_5_mM_TEMPO_T1_Intensity','10mW_5_mM_TEMPO_T2_Time_s','10mW_5_mM_TEMPO_T2_Intensity'])
#print(df.head(5))
time1=df['20mW_5_mM_TEMPO_T1_Time_s'].values
signal1=df['20mW_5_mM_TEMPO_T1_Intensity'].values
signal1=signal1/signal1.max()
t30_1=next((time1[i] for i in range(len(signal1)) if signal1[i] >= 0.3), None)
t90_1=next((time1[i] for i in range(len(signal1)) if signal1[i] >= 0.9), None)


time2=df['20mW_5_mM_TEMPO_T2_Time_s'].values
signal2=df['20mW_5_mM_TEMPO_T2_Intensity'].values
signal2=signal2/signal2.max()
t30_2=next((time2[i] for i in range(len(signal2)) if signal2[i] >= 0.3), None)
t90_2=next((time2[i] for i in range(len(signal2)) if signal2[i] >= 0.9), None)


print(f't30_1:{t30_1:.3f}s, t30_2:{t30_2:.3f}s, Time when signal reaches 30% DoC: {np.average([t30_1, t30_2]):.3f} s')
print(f't90_1:{t90_1:.3f}s, t90_2:{t90_2:.3f}s, Time when signal reaches 90% DoC: {np.average([t90_1, t90_2]):.3f} s')

for i in range(0,10):
    #print(i,signal1[i+1]-signal1[i])
    if np.abs((signal1[i+2]-signal1[i+1])/(signal1[i+1]-signal1[i]))>5:
        break
print('End of Inhibition T:',time1[i+1])
time1=time1[i+1:]
signal1=signal1[i+1:]

#plt.plot(time1,signal1,'--')

for i in range(0,10):
    #print(i,signal1[i+1]-signal1[i])
    if np.abs((signal2[i+2]-signal2[i+1])/(signal2[i+1]-signal2[i]))>5:
        break
print('End of Inhibition T:',time2[i+1])
time2=time2[i+1:]
signal2=signal2[i+1:]


def fitting_func(t,a,b):
    return 1-a*np.exp(np.minimum(b*(-t),0))

popt1, pcov1 = curve_fit(fitting_func, time1, signal1)
popt2, pcov2 = curve_fit(fitting_func, time2, signal2)
print('Fitted parameters for T1:', popt1)
print('Fitted parameters for T2:', popt2)
print(f'Average a={np.mean([popt1[0], popt2[0]]):.3f}')
print(f'Average b={np.mean([popt1[1], popt2[1]]):.3f}')

fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].scatter(time1, signal1, label='T1 Data', color='blue')
axes[0].plot(time1, fitting_func(time1, *popt1), label='T1 Fit', color='red')
axes[1].scatter(time2, signal2, label='T2 Data', color='green')
axes[1].plot(time2, fitting_func(time2, *popt2), label='T2 Fit', color='orange')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Normalized Intensity')
axes[1].set_xlabel('Time (s)')
axes[1].set_ylabel('Normalized Intensity')
axes[0].legend()
axes[1].legend()
fig.tight_layout()
plt.show()
# Out:
# t30_1:5.237s, t30_2:5.036s, Time when signal reaches 30% DoC: 5.136 s
# t90_1:7.856s, t90_2:7.654s, Time when signal reaches 90% DoC: 7.755 s
# End of Inhibition T: 2.01428
# End of Inhibition T: 2.014282
# Fitted parameters for T1: [2.25063013 0.2989301 ]
# Fitted parameters for T2: [2.31089692 0.31495956]
# Average a=2.281
# Average b=0.307

# %%
#This is for 0/5mM TEMPO (Jack Shared on 26/09/01)
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

x = np.linspace(0, 10, 20)
num_lines = 10
# 1. Choose a built-in Matplotlib colormap (e.g., 'viridis', 'plasma', 'coolwarm')
cmap = plt.colormaps['Blues']
line_colors = [cmap(i / (num_lines - 1)) for i in range(num_lines)]



file_path_1='.\\PastDataFiles\\analysis\\0mM_TEMPO\\120mW\\data\\0mM_TEMPO_120mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_1)
loc1=df.loc[(df['trial']==2) & (df['time_s']>=0)]
time1=loc1['time_s'].to_numpy(dtype=float)[:-400]
signal1=loc1['center_mean_16bit'].to_numpy(dtype=float)[:-400]
#signal1=loc1['offset_mean_16bit'].to_numpy(dtype=float)
signal1=signal1/signal1.max()
plt.figure(figsize=(10,6))
plt.plot(time1,signal1,label='0mM TEMPO 120mW/cm$^2$',linewidth=3,color=line_colors[8])

file_path_2='.\\PastDataFiles\\analysis\\0mM_TEMPO\\80mW\\data\\0mM_TEMPO_80mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_2)
loc2=df.loc[(df['trial']==1) & (df['time_s']>=0)]
time2=loc2['time_s'].to_numpy(dtype=float)[:-400]
signal2=loc2['center_mean_16bit'].to_numpy(dtype=float)[:-400]
#signal2=loc2['offset_mean_16bit'].to_numpy(dtype=float)
signal2=signal2/signal2.max()
plt.plot(time2,signal2,label='0mM TEMPO 80mW/cm$^2$',linewidth=3,color=line_colors[7])

file_path_3='.\\PastDataFiles\\analysis\\0mM_TEMPO\\60mW\\data\\0mM_TEMPO_60mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_3)
loc3=df.loc[(df['trial']==2) & (df['time_s']>=0)]
time3=loc3['time_s'].to_numpy(dtype=float)[:-600]
signal3=loc3['center_mean_16bit'].to_numpy(dtype=float)[:-600]
#signal3=loc3['offset_mean_16bit'].to_numpy(dtype=float)
signal3=signal3/signal3.max()
plt.plot(time3,signal3,label='0mM TEMPO 60mW/cm$^2$',linewidth=3,color=line_colors[6])

file_path_4='.\\PastDataFiles\\analysis\\0mM_TEMPO\\50mW\\data\\0mM_TEMPO_50mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_4)
loc4=df.loc[(df['trial']==1) & (df['time_s']>=0)]
time4=loc4['time_s'].to_numpy(dtype=float)[:-400]
signal4=loc4['center_mean_16bit'].to_numpy(dtype=float)[:-400]
#signal4=loc4['offset_mean_16bit'].to_numpy(dtype=float)
signal4=signal4/signal4.max()
plt.plot(time4,signal4,label='0mM TEMPO 50mW/cm$^2$',linewidth=3,color=line_colors[5])

file_path_5='.\\PastDataFiles\\analysis\\0mM_TEMPO\\40mW\\data\\0mM_TEMPO_40mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_5)
loc5=df.loc[(df['trial']==1) & (df['time_s']>=0)]
time5=loc5['time_s'].to_numpy(dtype=float)[:-550]
signal5=loc5['center_mean_16bit'].to_numpy(dtype=float)[:-550]
#signal5=loc5['offset_mean_16bit'].to_numpy(dtype=float)
signal5=signal5/signal5.max()
plt.plot(time5,signal5,label='0mM TEMPO 40mW/cm$^2$',linewidth=3,color=line_colors[4])

file_path_6='.\\PastDataFiles\\analysis\\0mM_TEMPO\\30mW\\data\\0mM_TEMPO_30mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_6)
loc6=df.loc[(df['trial']==1) & (df['time_s']>=0)]
time6=loc6['time_s'].to_numpy(dtype=float)[:-350]
signal6=loc6['center_mean_16bit'].to_numpy(dtype=float)[:-350]
#signal6=loc6['offset_mean_16bit'].to_numpy(dtype=float)
signal6=signal6/signal6.max()
plt.plot(time6,signal6,label='0mM TEMPO 30mW/cm$^2$',linewidth=3,color=line_colors[3])

plt.axvline(x=0.1, color='black', linestyle='--', linewidth=2)
plt.text(0.15, 0.99, 'Exposure \n onset', rotation=0, va='top', ha='left', fontsize=12)

plt.ylim(0,1.05)
plt.yticks(np.arange(0,1.05,0.1),fontsize=12)
plt.xlim(0,6)
plt.xticks(0.5*np.arange(12),fontsize=12)
plt.xlabel('Time (s)',fontsize=12)
plt.ylabel('Normalized Fluorescence Signal (a.u.)',fontsize=12)
plt.title('Normalized Fluorescence Signal vs Time (0mMoL TEMPO)',fontsize=14)
plt.legend(fontsize=12)

# %%
#This is for 0/5mM TEMPO (Jack Shared on 26/09/01)
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

x = np.linspace(0, 10, 20)
num_lines = 10
# 1. Choose a built-in Matplotlib colormap (e.g., 'viridis', 'plasma', 'coolwarm')
cmap = plt.colormaps['Reds']
line_colors = [cmap(i / (num_lines - 1)) for i in range(num_lines)]


file_path_1='.\\PastDataFiles\\analysis\\5mM_TEMPO\\120mW\\data\\5mM_TEMPO_120mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_1)
loc1=df.loc[(df['trial']==3) & (df['time_s']>=0)]
time1=loc1['time_s'].to_numpy(dtype=float)[:-300]
signal1=loc1['center_mean_16bit'].to_numpy(dtype=float)[:-300]
#signal1=loc1['offset_mean_16bit'].to_numpy(dtype=float)
signal1=signal1/signal1.max()
plt.figure(figsize=(10,6))
plt.plot(time1,signal1,label='5mM TEMPO 120mW/cm$^2$',linewidth=3,color=line_colors[9])

file_path_7='.\\PastDataFiles\\analysis\\5mM_TEMPO\\100mW\\data\\5mM_TEMPO_100mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_7)
loc7=df.loc[(df['trial']==1) & (df['time_s']>=0)]
time7=loc7['time_s'].to_numpy(dtype=float)[:-400]
signal7=loc7['center_mean_16bit'].to_numpy(dtype=float)[:-400]
#signal7=loc7['offset_mean_16bit'].to_numpy(dtype=float)
signal7=signal7/signal7.max()
plt.plot(time7,signal7,label='5mM TEMPO 80mW/cm$^2$',linewidth=3,color=line_colors[8])

file_path_2='.\\PastDataFiles\\analysis\\5mM_TEMPO\\80mW\\data\\5mM_TEMPO_80mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_2)
loc2=df.loc[(df['trial']==1) & (df['time_s']>=0)]
time2=loc2['time_s'].to_numpy(dtype=float)[:-400]
signal2=loc2['center_mean_16bit'].to_numpy(dtype=float)[:-400]
#signal2=loc2['offset_mean_16bit'].to_numpy(dtype=float)
signal2=signal2/signal2.max()
plt.plot(time2,signal2,label='5mM TEMPO 80mW/cm$^2$',linewidth=3,color=line_colors[7])

file_path_3='.\\PastDataFiles\\analysis\\5mM_TEMPO\\60mW\\data\\5mM_TEMPO_60mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_3)
loc3=df.loc[(df['trial']==2) & (df['time_s']>=0)]
time3=loc3['time_s'].to_numpy(dtype=float)[:-300]
signal3=loc3['center_mean_16bit'].to_numpy(dtype=float)[:-300]
#signal3=loc3['offset_mean_16bit'].to_numpy(dtype=float)
signal3=signal3/signal3.max()
plt.plot(time3,signal3,label='5mM TEMPO 60mW/cm$^2$',linewidth=3,color=line_colors[6])

file_path_4='.\\PastDataFiles\\analysis\\5mM_TEMPO\\50mW\\data\\5mM_TEMPO_50mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_4)
loc4=df.loc[(df['trial']==1) & (df['time_s']>=0)]
time4=loc4['time_s'].to_numpy(dtype=float)[:-400]
signal4=loc4['center_mean_16bit'].to_numpy(dtype=float)[:-400]
#signal4=loc4['offset_mean_16bit'].to_numpy(dtype=float)
signal4=signal4/signal4.max()
plt.plot(time4,signal4,label='5mM TEMPO 50mW/cm$^2$',linewidth=3,color=line_colors[5])

file_path_5='.\\PastDataFiles\\analysis\\5mM_TEMPO\\40mW\\data\\5mM_TEMPO_40mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_5)
loc5=df.loc[(df['trial']==4) & (df['time_s']>=0)]
time5=loc5['time_s'].to_numpy(dtype=float)[:-350]
signal5=loc5['center_mean_16bit'].to_numpy(dtype=float)[:-350]
#signal5=loc5['offset_mean_16bit'].to_numpy(dtype=float)
signal5=signal5/signal5.max()
plt.plot(time5,signal5,label='5mM TEMPO 40mW/cm$^2$',linewidth=3,color=line_colors[4])

file_path_6='.\\PastDataFiles\\analysis\\5mM_TEMPO\\30mW\\data\\5mM_TEMPO_30mW_center_and_offset_roi_timeseries.csv'
df=pd.read_csv(file_path_6)
loc6=df.loc[(df['trial']==1) & (df['time_s']>=0)]
time6=loc6['time_s'].to_numpy(dtype=float)[:-350]
signal6=loc6['center_mean_16bit'].to_numpy(dtype=float)[:-350]
#signal6=loc6['offset_mean_16bit'].to_numpy(dtype=float)
signal6=signal6/signal6.max()
plt.plot(time6,signal6,label='5mM TEMPO 30mW/cm$^2$',linewidth=3,color=line_colors[3])

plt.axvline(x=0.1, color='black', linestyle='--', linewidth=2)
plt.text(0.15, 0.99, 'Exposure \n onset', rotation=0, va='top', ha='left', fontsize=12)

plt.ylim(0,1.05)
plt.yticks(np.arange(0,1.05,0.1),fontsize=12)
plt.xlim(0,11)
plt.xticks(1*np.arange(12),fontsize=12)
plt.xlabel('Time (s)',fontsize=12)
plt.ylabel('Normalized Fluorescence Signal (a.u.)',fontsize=12)
plt.title('Normalized Fluorescence Signal vs Time (5mM TEMPO)',fontsize=14)
plt.legend(fontsize=12)

# %%
#Zak asked for, Done based on the data from Jack, 26/09/01
#Log-log (power-law) fit of polymerization rate B vs excitation intensity, analogous to Figure 2C in
#O'Dea, Scruggs, Page, Adv. Funct. Mater. 2026, 36, e30758 (rp ~ I^n; Type I slope=0.64, Type II slope=0.53)
#https://advanced.onlinelibrary.wiley.com/doi/epdf/10.1002/adfm.202530758 Reference sources
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import LogLocator, ScalarFormatter,FixedLocator, FuncFormatter

datasets = {
    '0mM TEMPO': {
        'intensity': np.array([30, 40, 50, 60, 80, 120], dtype=float),
        'b': np.array([0.8707, 1.0447, 1.1906, 1.3293, 1.5562, 1.9032]),
        'color': 'blue',
    },
    '5mM TEMPO': {
        'intensity': np.array([30, 40, 50, 60, 80, 100, 120], dtype=float),
        'b': np.array([0.5625, 0.6443, 0.7798, 0.9445, 1.2024, 1.3228, 1.5049]),
        'color': 'red',
    },
}

plt.figure(figsize=(10, 6))
ax = plt.gca()
for label, d in datasets.items():
    I, b, color = d['intensity'], d['b'], d['color']
    log_I, log_b = np.log10(I), np.log10(b)

    n_fit, log_k = np.polyfit(log_I, log_b, 1)
    b_fit = 10**log_k * I**n_fit
    r2 = 1 - np.sum((b - b_fit)**2) / np.sum((b - np.mean(b))**2)

    plt.loglog(I, b, 'o', color=color, label=f'{label} data')
    I_smooth = np.logspace(np.log10(I.min()), np.log10(I.max()), 50)
    
    fit_values = 10**log_k * I_smooth**n_fit
    plt.loglog(I_smooth, fit_values, '--', color=color,
                   label=f'{label} fit: n={n_fit:.2f}, $R^2$={r2:.3f}')

    
    annotation_x = I_smooth[int(0.72 * len(I_smooth))]
    annotation_y = 10**log_k * annotation_x**n_fit
    ax.annotate(f'slope = {n_fit:.2f}', (annotation_x, annotation_y),
                color=color, fontsize=12, ha='right', va='bottom',
                xytext=(-50, -10), textcoords='offset points')

    print(f'{label}:Polymerization Rate B = {10**log_k:.3f} * I^{n_fit:.3f}  (R^2 = {r2:.4f})')

plt.xlabel('Exposure Intensity (mW/cm$^2$)',fontsize=12)
plt.ylabel('Polymerization Rate, B (s$^{-1}$)',fontsize=12)
plt.title("DLP__Polymerization Rate vs Intensity (Log-Log Fit)",fontsize=14)
# --- finer ticks ---8
ax.xaxis.set_minor_locator(LogLocator(subs=np.arange(2, 10) * 0.1))
ax.xaxis.set_major_locator(FixedLocator([ 30, 40, 50, 60, 80, 100,120]))
ax.xaxis.set_major_formatter(FuncFormatter(lambda x, pos: f'{x:g}'))
ax.yaxis.set_minor_locator(LogLocator(subs=np.arange(2, 10) * 0.1))
ax.yaxis.set_minor_formatter(ScalarFormatter())
ax.yaxis.set_major_formatter(ScalarFormatter())
plt.legend()
plt.grid(True, which='both', ls=':', alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# 0mM TEMPO:Polymerization Rate B = 0.130 * I^0.565  (R^2 = 0.9970)
# 5mM TEMPO:Polymerization Rate B = 0.043 * I^0.745  (R^2 = 0.9892)

# %%
# Log-log (power-law) fit of inhibition time vs excitation intensity
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import LogLocator, ScalarFormatter,FixedLocator, FuncFormatter

datasets_inhibition = {
    '0mM TEMPO': {
        'intensity': np.array([30, 40, 50, 60, 80, 120], dtype=float),
        'inhibition_time': np.array([1.0273, 0.8405, 0.6985, 0.6144, 0.5320, 0.3726]),
        'color': 'blue',
    },
    '5mM TEMPO': {
        'intensity': np.array([30, 40, 50, 60, 80, 100, 120], dtype=float),
        'inhibition_time': np.array([3.8170, 2.6200, 2.4345, 2.0319, 1.6434, 1.3730, 1.0482]),
        'color': 'red',
    },
}

plt.figure(figsize=(10, 6))
ax = plt.gca()
for label, d in datasets_inhibition.items():
    intensity = d['intensity']
    inhibition_time = d['inhibition_time']
    color = d['color']
    log_intensity, log_time = np.log10(intensity), np.log10(inhibition_time)

    slope, log_k = np.polyfit(log_intensity, log_time, 1)
    time_fit = 10**log_k * intensity**slope
    r2 = 1 - np.sum((inhibition_time - time_fit)**2) / np.sum((inhibition_time - np.mean(inhibition_time))**2)

    plt.loglog(intensity, inhibition_time, 'o', color=color, label=f'{label} data')
    intensity_smooth = np.logspace(np.log10(intensity.min()), np.log10(intensity.max()), 50)
    fit_values = 10**log_k * intensity_smooth**slope
    plt.loglog(intensity_smooth, fit_values, '--', color=color,
               label=f'{label} fit: n={slope:.2f}, $R^2$={r2:.3f}')

    annotation_x = intensity_smooth[int(0.72 * len(intensity_smooth))]
    annotation_y = 10**log_k * annotation_x**slope
    ax.annotate(f'slope = {slope:.2f}', (annotation_x, annotation_y),
                color=color, fontsize=12, ha='right', va='bottom',
                xytext=(-50, -10), textcoords='offset points')

    print(f'{label}: inhibition time C= {10**log_k:.4f} * I^{slope:.4f}  (R^2 = {r2:.4f})')

plt.xlabel('Exposure Intensity (mW/cm$^2$)', fontsize=12)
plt.ylabel('Inhibition Time (s)', fontsize=12)
plt.title('DLP__Inhibition Time vs Intensity (Log-Log Fit)', fontsize=14)
ax.xaxis.set_minor_locator(LogLocator(subs=np.arange(2, 10) * 0.1))
ax.xaxis.set_major_locator(FixedLocator([ 30, 40, 50, 60, 80, 100,120]))
ax.xaxis.set_major_formatter(FuncFormatter(lambda x, pos: f'{x:g}'))
ax.yaxis.set_minor_locator(LogLocator(subs=np.arange(2, 10) * 0.1))
ax.yaxis.set_minor_formatter(ScalarFormatter())
ax.yaxis.set_major_formatter(ScalarFormatter())
plt.legend()
plt.grid(True, which='both', ls=':', alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# 0mM TEMPO: inhibition time C= 11.7591 * I^-0.7170  (R^2 = 0.9965)
# 5mM TEMPO: inhibition time C= 68.6483 * I^-0.8604  (R^2 = 0.9807)
